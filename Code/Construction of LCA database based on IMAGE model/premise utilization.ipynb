# %%
bw2data.projects.set_current("PSC-LCA")
bw2data.databases
list(bw2data.databases)
# Out:
# ['biosphere3',
#  'ecoinvent 3.8_cutoff_ecoSpold02',
#  'ecoinvent_cutoff_3.8_image_SSP2-Base_2030',
#  'ecoinvent_cutoff_3.8_image_SSP2-Base_2040',
#  'ecoinvent_cutoff_3.8_image_SSP2-Base_2050',
#  'PSC-Base-2030',
#  'PSC-SS2-BASE-2040',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP26_2030',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP26_2040',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP26_2050',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP19_2030',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP19_2040',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP19_2050',
#  'PSC-SS2-BASE-2050',
#  'PSC-SS2-26-2030',
#  'PSC-SS2-26-2040',
#  'PSC-SS2-26-2050',
#  'PSC-SS2-19-2030',
#  'PSC-SS2-19-2040',
#  'PSC-SS2-19-2050',
#  'D--B-2030',
#  'D--B-2040',
#  'D--B-2050',
#  'D--RCP26-2030',
#  'D--RCP26-2040',
#  'D--RCP26-2050',
#  'D--RCP19-2030',
#  'D-RCP19-2040',
#  'D--RCP19-2050',
#  'PSC-SS2-BASE-2035',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP19_2025',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP19_2035',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP19_2045',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP26_2025',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP26_2035',
#  'ecoinvent_cutoff_3.8_image_SSP2-RCP26_2045',
#  'ecoinvent_cutoff_3.8_image_SSP2-Base_2025',
#  'ecoinvent_cutoff_3.8_image_SSP2-Base_2035',
#  'ecoinvent_cutoff_3.8_image_SSP2-Base_2045']

# %%
clear_cache()
# Out:
# Cache folder cleared!

# %%
ndb = NewDatabase(
    scenarios=[
        {"model":"image", "pathway":"SSP2-RCP19", "year":2025},
        {"model":"image", "pathway":"SSP2-RCP19", "year":2035},
        {"model":"image", "pathway":"SSP2-RCP19", "year":2045},
        {"model":"image", "pathway":"SSP2-RCP26", "year":2025},
        {"model":"image", "pathway":"SSP2-RCP26", "year":2035},
        {"model":"image", "pathway":"SSP2-RCP26", "year":2045},
        {"model":"image", "pathway":"SSP2-Base", "year":2025},
        {"model":"image", "pathway":"SSP2-Base", "year":2035},
        {"model":"image", "pathway":"SSP2-Base", "year":2045},
    ],
    source_db="ecoinvent 3.8_cutoff_ecoSpold02", # <-- name of the database in the BW2 project. Must be a string.
    source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
    key='xxx' # <-- decryption key
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
)
# Out:
# premise v.(1, 5, 7)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|██████████| 19565/19565 [00:00<00:00, 64925.41it/s]
# Adding exchange data to activities
# 100%|██████████| 629959/629959 [00:27<00:00, 23214.44it/s]
# Filling out exchange data
# 100%|██████████| 19565/19565 [00:02<00:00, 8869.00it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Extracted 1 worksheets in 0.77 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.33 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 7 worksheets in 0.06 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.72 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +----------------------------------------------------+--------------------------------+----------+-------------+
# |                        Name                        |       Reference product        | Location |     File    |
# +----------------------------------------------------+--------------------------------+----------+-------------+
# |          fluorspar production, 97% purity          |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# |     metallization paste production, back side      | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production, back side, alumini | metallization paste, back side |   RER    | lci-PV.xlsx |
# |     metallization paste production, front side     | metallization paste, front sid |   RER    | lci-PV.xlsx |
# | photovoltaic module production, building-integrate | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production, building-integrate | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system production, for facad | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system production, for flat- | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system production, for slant | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# |      photovoltaic panel factory construction       |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |            polyvinylfluoride production            |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# |      polyvinylfluoride production, dispersion      | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# |         polyvinylfluoride, film production         |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# |      silicon production, metallurgical grade       |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# |             vinyl fluoride production              |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |             wafer factory construction             |         wafer factory          |    DE    | lci-PV.xlsx |
# +----------------------------------------------------+--------------------------------+----------+-------------+
# Extracted 1 worksheets in 0.05 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.20 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +----------------------------------------------------+--------------------------------+----------+---------------------------------------------------+
# |                        Name                        |       Reference product        | Location |                        File                       |
# +----------------------------------------------------+--------------------------------+----------+---------------------------------------------------+
# | carbon dioxide, captured at cement production plan | carbon dioxide, captured and r |   RER    | lci-synfuels-from-methanol-from-cement-plant.xlsx |
# +----------------------------------------------------+--------------------------------+----------+---------------------------------------------------+
# Extracted 1 worksheets in 0.00 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +----------------------------------------------------+----------------------+----------+-------------------------------------------+
# |                        Name                        |  Reference product   | Location |                    File                   |
# +----------------------------------------------------+----------------------+----------+-------------------------------------------+
# | methanol distillation, hydrogen from coal gasifica |  methanol, purified  |   RER    | lci-synfuels-from-methanol-from-coal.xlsx |
# | methanol synthesis, hydrogen from coal gasificatio | methanol, unpurified |   RER    | lci-synfuels-from-methanol-from-coal.xlsx |
# +----------------------------------------------------+----------------------+----------+-------------------------------------------+
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 4 worksheets in 0.22 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.13 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Done!
#
# Data cached. It is advised to restart your workflow at this point.
# This allows premise to use the cached data instead, which results in
# a faster workflow.
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Done!

# %%
ndb = NewDatabase(
    scenarios=[
        {"model":"image", "pathway":"SSP2-Base", "year":2030},
        {"model":"image", "pathway":"SSP2-Base", "year":2040},
    ],
    source_db="ecoinvent 3.8_cutoff_ecoSpold02", # <-- name of the database in the BW2 project. Must be a string.
    source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
    key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
)
# Out:
# premise v.(1, 5, 7)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Done!

# %%
ndb = NewDatabase(
    scenarios=[
        {"model":"image", "pathway":"SSP2-Base", "year":2050},
    ],
    source_db="ecoinvent 3.8_cutoff_ecoSpold02", # <-- name of the database in the BW2 project. Must be a string.
    source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
    key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
)
# Out:
# premise v.(1, 5, 7)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Done!

# %%
ndb.update_electricity()
# Out:
# /////////////////////////// ELECTRICITY ////////////////////////////
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway2.
# Prepare database 1.
# - check for duplicates...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:29
# Title: Writing activities to SQLite3 database:
#   Started: 09/14/2023 14:41:20
#   Finished: 09/14/2023 14:41:50
#   Total time elapsed: 00:00:29
#   CPU %: 71.30
#   Memory %: 24.39
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP19_2030
# Prepare database 2.
# - check for duplicates...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:29
# Title: Writing activities to SQLite3 database:
#   Started: 09/14/2023 14:44:29
#   Finished: 09/14/2023 14:44:58
#   Total time elapsed: 00:00:29
#   CPU %: 69.30
#   Memory %: 26.58
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP19_2040
# Prepare database 3.
# - check for duplicates...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:30
# Title: Writing activities to SQLite3 database:
#   Started: 09/14/2023 14:48:36
#   Finished: 09/14/2023 14:49:07
#   Total time elapsed: 00:00:30
#   CPU %: 72.70
#   Memory %: 28.00
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP19_2050
# Generate scenario report.
# Report saved under C:\Users\Lenovo\export\scenario_report.
# Generate change report.
# Report saved under C:\Users\Lenovo.

# %%
ndb.update_all()
# Out:
# `update_all()` will skip the following steps:
# update_two_wheelers(), update_cars(), and update_buses()
# If you want to update these steps, please run them separately afterwards.
#
# ////////////////// MEDIUM AND HEAVY DUTY TRUCKS ////////////////////
# Extracted 1 worksheets in 5.92 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 5.90 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 4.62 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 5.79 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 5.85 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 5.88 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 5.96 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 4.76 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 4.65 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
#
# /////////////////////////// ELECTRICITY ////////////////////////////
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Coal IGCC CCS
#
# //////////////////////// DIRECT AIR CAPTURE ////////////////////////
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
#
# ///////////////////////////// CEMENT //////////////////////////////
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
#
# ////////////////////////////// STEEL //////////////////////////////
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
# Create new steel production datasets and empty old datasets
# Create pig iron production datasets
#
# ////////////////////////////// FUELS ///////////////////////////////
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> hydrogen
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
#
# /////////////////////////// EMISSIONS //////////////////////////////
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway2.
# Prepare database 1.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:33
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 15:40:12
#   Finished: 09/25/2023 15:40:45
#   Total time elapsed: 00:00:33
#   CPU %: 80.00
#   Memory %: 36.59
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP19_2025
# Prepare database 2.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:34
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 15:46:51
#   Finished: 09/25/2023 15:47:26
#   Total time elapsed: 00:00:34
#   CPU %: 74.80
#   Memory %: 38.28
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP19_2035
# Prepare database 3.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:35
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 15:54:05
#   Finished: 09/25/2023 15:54:40
#   Total time elapsed: 00:00:35
#   CPU %: 82.70
#   Memory %: 39.71
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP19_2045
# Prepare database 4.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:34
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 16:02:04
#   Finished: 09/25/2023 16:02:38
#   Total time elapsed: 00:00:34
#   CPU %: 76.50
#   Memory %: 41.01
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP26_2025
# Prepare database 5.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:34
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 16:10:30
#   Finished: 09/25/2023 16:11:05
#   Total time elapsed: 00:00:34
#   CPU %: 80.70
#   Memory %: 39.68
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP26_2035
# Prepare database 6.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:35
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 16:19:17
#   Finished: 09/25/2023 16:19:52
#   Total time elapsed: 00:00:35
#   CPU %: 76.20
#   Memory %: 37.75
# Created database: ecoinvent_cutoff_3.8_image_SSP2-RCP26_2045
# Prepare database 7.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:32
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 16:28:40
#   Finished: 09/25/2023 16:29:13
#   Total time elapsed: 00:00:32
#   CPU %: 66.00
#   Memory %: 35.15
# Created database: ecoinvent_cutoff_3.8_image_SSP2-Base_2025
# Prepare database 8.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:35
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 16:38:18
#   Finished: 09/25/2023 16:38:54
#   Total time elapsed: 00:00:35
#   CPU %: 76.90
#   Memory %: 30.81
# Created database: ecoinvent_cutoff_3.8_image_SSP2-Base_2035
# Prepare database 9.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:36
# Title: Writing activities to SQLite3 database:
#   Started: 09/25/2023 16:48:52
#   Finished: 09/25/2023 16:49:29
#   Total time elapsed: 00:00:36
#   CPU %: 42.70
#   Memory %: 27.54
# Created database: ecoinvent_cutoff_3.8_image_SSP2-Base_2045
# Generate scenario report.
# Report saved under C:\Users\Lenovo\export\scenario_report.
# Generate change report.
# Report saved under C:\Users\Lenovo.
